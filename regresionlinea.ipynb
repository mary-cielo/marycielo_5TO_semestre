# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.DataFrame()
df["area"]=[2600,3000,3200,3600,4000]
df["precio"]=[550000,565000,610000,680000,725000]

# %%
plt.scatter(df["area"],df["precio"])

# %%
X=df[["area"]]

# %%
Y=df["precio"]

# %%
modelo=linear_model.LinearRegression()

# %%
modelo.fit(X,Y)
# Out:
# LinearRegression()

# %%
modelo.predict([[5300]])
# Out:
# c:\Users\Alumno23\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([900291.09589041])

# %%
plt.plot(df["area"], modelo.predict(X))

# %%
plt.scatter(df["area"], df["precio"])
plt.plot(df["area"], modelo.predict(X))
